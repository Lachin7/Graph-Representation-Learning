# %% [markdown]
# # Introduction
# Welcome to the first practical for Graph Representation Learning. In this practical, we will be covering the content of the lectures about TransE.
#
# We will be using [PyTorch](https://pytorch.org/docs/stable/index.html) to implement TransE from scratch, building it up piece by piece.
#
# The main goal of this practical is to create a working implementation of TransE. There are also two optional parts: *filtered negative sampling* and *RotatE*.
#
# The notebook is divided into sections, each of which comes with complete or partially completed code. Before each snippet of code there will be a description of what we are about to implement. The sections of code you need to complete are marked as **Tasks**. The majority of the length of this practical comes from code already written for you, so don't panic at the apparent length! There are only 8 tasks for you to complete.
#
# Please ensure that you operate within the framework given in the notebook and bring any questions you may have to the practical demonstrators. We suggest that you **DO NOT** edit code that is a part of the framework, since this will make it more difficult for demonstrators to assist if your code is broken.
#
# Since we are working in a Jupyter Notebook, the code is very interactive. When you're stuck on something, try adding a new block of code below what you're working on and using it to debug your code. If you are new to Jupyter Notebooks, see [here](https://www.youtube.com/watch?v=inN8seMm7UI&ab_channel=TensorFlow) for a brief introduction video. If you are using Google Colab (which we recommend doing), please ensure you have changed the runtime type to use a GPU, as it will make your code run much faster.

# %% [markdown]
# # Imports
#
# Run the following blocks of code to install and import and the necessary python packages.

# %%
# %%capture
# !pip install "pykeen<1.11.0"

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import pykeen
import argparse
import json
import os
import random

from torch.utils.data import Dataset, DataLoader
from torch.utils import data as torch_data
from sklearn.metrics import average_precision_score
from pykeen.datasets import Nations
from typing import List, Tuple
# Out:
# INFO:pykeen.utils:Using opt_einsum

# %% [markdown]
# # Dataset

# %% [markdown]
# ## Loading Nations from `pykeen`
# We will use `pykeen` to load the `Nations` dataset, which is a small knowledge graph with 14 entities, 55 relations, and 1992 triples describing countries and their political relationships.
#
# We first define a function to convert the `pykeen` datasets to lists of triples. We then create 3 lists of triples: one for training, one for validation, and one for testing.

# %%
def create_triples_from_pykeen_dataset(dataset: pykeen.triples.triples_factory.TriplesFactory):
    slcwa_instances=dataset.create_slcwa_instances(
        batch_size=1,
        shuffle=True,
    )
    positive_dataset = [tuple(batch.positives[0].tolist()) for batch in slcwa_instances]
    return positive_dataset

# %%
dataset = Nations()
train_triples = create_triples_from_pykeen_dataset(dataset.training)
valid_triples = create_triples_from_pykeen_dataset(dataset.validation)
test_triples = create_triples_from_pykeen_dataset(dataset.testing)

# %% [markdown]
# #### Task 1
# Define a function `id_triple_as_labels` that takes in a triple of entity/relation ids and returns a triple of labels.
#
# *Hint: use the dictionaries `id2entity` and `id2relation` provided below*

# %%
id2entity = dataset.training.entity_id_to_label
id2relation = dataset.training.relation_id_to_label

### BEGIN SOLUTION
def id_triple_as_labels(triple: Tuple):
    return (id2entity[triple[0]], id2relation[triple[1]], id2entity[triple[2]])
### END SOLUTION

# %% [markdown]
# We can then run the following cell to see some of the facts from the **Nations** dataset.

# %%
for i in range(10):
    print(train_triples[i])
    print(id_triple_as_labels(train_triples[i]))
# Out:
# (5, 8, 7)
# ('india', 'commonbloc2', 'israel')
# (4, 7, 9)
# ('egypt', 'commonbloc1', 'netherlands')
# (0, 18, 11)
# ('brazil', 'exports3', 'uk')
# (9, 7, 7)
# ('netherlands', 'commonbloc1', 'israel')
# (4, 42, 9)
# ('egypt', 'reltreaties', 'netherlands')
# (5, 9, 12)
# ('india', 'conferences', 'usa')
# (8, 39, 4)
# ('jordan', 'relngo', 'egypt')
# (3, 27, 9)
# ('cuba', 'ngo', 'netherlands')
# (13, 20, 10)
# ('ussr', 'intergovorgs', 'poland')
# (9, 28, 0)
# ('netherlands', 'ngoorgs3', 'brazil')

# %% [markdown]
# ## Negative Sampling
# Simply training on positive facts will not suffice, since the model will then learn to just maximise the similarity measure for every possible fact in the database. Thus, for each positive fact, we need to sample a set of corrupted facts.

# %% [markdown]
# #### Task 2
# First, define a function `get_corrupted_entities` that takes in a single positive sample and returns an array of corrupted entities. The positive sample is a tuple of integers, representing the IDs of the entities/relation.
#
# The function should also take in `train_dataset`, as you will need to access `train_dataset.negative_sample_size` (the number of corrupted entities to sample), `train_dataset.nentity` (the number of entities in the knowledge graph), and possibly `train_dataset.true_head` / `train_dataset.true_tail` (dictionaries providing the set of all known true triples for the given head / tail). The keys for the train_dataset.true_head dictionary are tuples of the form (relation, tail), and the keys for train_dataset.true_tail are tuples of the form (head, relation). The full definition of `TrainDataset` can be found further below if you need to refer to it.
#
# The function should also take in `mode`, which, if set to `mode == 'head'`, indicates that the head entity should be corrupted, and likewise the tail entity if `mode == 'tail'`. Your output should be a numpy array with shape `[train_dataset.negative_sample_size]`.
#
# Note: as an optional extra, you can sample corrupted entities such that the resulting triples are not known to be true in the knowledge graph. If you get stuck on this, first implement a simpler solution first and then come back to it later.

# %%
### BEGIN SOLUTION
def get_corrupted_entities(positive_sample: Tuple, train_dataset: Dataset, mode: str) -> np.ndarray:
    head, relation, tail = positive_sample
    corrupted_entities = []

    num_samples = train_dataset.negative_sample_size
    total_entities = train_dataset.nentity

    known_true_triples = (
        train_dataset.true_tail if mode == 'tail' else train_dataset.true_head
    )
    true_triple_key = (head, relation) if mode == 'tail' else (relation, tail)

    while len(corrupted_entities) < num_samples:
        corrupted_entity = np.random.randint(total_entities)

        if corrupted_entity not in known_true_triples.get(true_triple_key, set()):
            corrupted_entities.append(corrupted_entity)

    return np.array(corrupted_entities)
### END SOLUTION

# %% [markdown]
# #### Task 3
# Next, we can create the negative samples using the corrupted entities. Define a function `get_negative_sample` which takes in a positive sample and corrupted head/tail entities, which will be created by the `get_corrupted_entities` function we defined above (do not call to the above function, the corrupted entities will be passed in as arguments).
#
# The argument `positive_sample` is a tuple `(head, relation, tail)`. The arguments `corrupted_head_entities` and `corrupted_tail_entities` should have shape `[negative_sample_size]` each.
#
# Your function should return a `numpy` array with shape `[2*negative_sample_size, 3]`, by combining the corrupted entities with the positive sample.

# %%
### BEGIN SOLUTION
def get_negative_sample(positive_sample, corrupted_head_entities, corrupted_tail_entities):
    corrupted_head_samples = np.zeros((corrupted_head_entities.shape[0], 3))
    corrupted_head_samples[:, 0] = corrupted_head_entities
    corrupted_head_samples[:, 1:3] = positive_sample[1:3]

    corrupted_tail_samples = np.zeros((corrupted_tail_entities.shape[0], 3))
    corrupted_tail_samples[:, 2] = corrupted_tail_entities
    corrupted_tail_samples[:, 0:2] = positive_sample[0:2]

    return np.concatenate((corrupted_head_samples, corrupted_tail_samples), axis=0)
### END SOLUTION

# %% [markdown]
# ## Train Dataset
# Now that we have written the functions we need to perform our negative sampling, let's combine everything together to create our `torch` training dataset.
#
# Notice that in the `__get_item__` function, we convert the samples to `torch` tensors before we return them. Up to this point, we have been working with `numpy` arrays; `torch` tensors have the same structure, but are optimised to run on the `GPU` and can also track gradients to be used for optimising parameters.

# %%
class TrainDataset(Dataset):
    def __init__(self, triples, nentity, nrelation, negative_sample_size):
        self.len = len(triples)
        self.triples = triples # all training triples
        self.triple_set = set(triples) # unique triples
        self.nentity = nentity # number of entities in the knowledge graph
        self.nrelation = nrelation # number of relations in the knowledge graph
        self.negative_sample_size = negative_sample_size // 2 # Half from heads, half from tails

        # known triples for the given heads / tails
        self.true_head, self.true_tail = self.get_true_head_and_tail(self.triples)

    def __len__(self):
        return self.len

    def __getitem__(self, idx):
        '''
        Get an item from the Dataset.
        '''
        # Fetch a positive sample
        positive_sample = self.triples[idx]

        # Sample corrupted head and tail entities
        corrupted_head_entities = get_corrupted_entities(positive_sample, self, 'head')
        corrupted_tail_entities = get_corrupted_entities(positive_sample, self, 'tail')

        # Create the negative sample
        negative_sample = get_negative_sample(positive_sample, corrupted_head_entities, corrupted_tail_entities)

        # Convert samples to torch tensors
        negative_sample = torch.LongTensor(negative_sample)
        positive_sample = torch.LongTensor(positive_sample)

        return positive_sample, negative_sample

    @staticmethod
    def collate_fn(data):
        positive_sample = torch.stack([_[0] for _ in data], dim=0)
        negative_sample = torch.stack([_[1] for _ in data], dim=0)
        return positive_sample, negative_sample

    @staticmethod
    def get_true_head_and_tail(triples):
        '''
        Build a dictionary of true triples that will
        be used to filter these true triples for negative sampling
        '''

        true_head = {}
        true_tail = {}

        for head, relation, tail in triples:
            if (head, relation) not in true_tail:
                true_tail[(head, relation)] = []
            true_tail[(head, relation)].append(tail)
            if (relation, tail) not in true_head:
                true_head[(relation, tail)] = []
            true_head[(relation, tail)].append(head)

        for relation, tail in true_head:
            true_head[(relation, tail)] = np.array(list(set(true_head[(relation, tail)])))
        for head, relation in true_tail:
            true_tail[(head, relation)] = np.array(list(set(true_tail[(head, relation)])))

        return true_head, true_tail

# %% [markdown]
# ## Test Dataset
# We will use a seperate dataset for our testing, with the batch size always set to 1. The test dataset will have two modes: `'head-batch'` and `'tail-batch'`. In the first mode, the dataset should return a positive sample and a list of all possible heads, and similarly for the second mode.
#
# Since we are doing filtered evaluation, we do not want triples which are known to be true to affect the ranking. Thus, we will filter the heads / tails out of our samples that yield triples which are known to be true.

# %% [markdown]
# #### Task 4
# Write a function `get_filtered_test_sample` that takes in a positive triple (`head, relation, tail`) and the `test_dataset` (which can be found further below). The function should return a list of size `test_dataset.nentity`, where each element is the ID of an entity. It is important for the downstream ranking that we ensure the list is this size.
#
# To filter the sample, if for some entity `x`, `(x, relation, tail)` already appears in the set of known triples, instead replace it with `head`. The set of known triples can be accessed by `test_dataset.triple_set`. You will need to check the value of `test_dataset.mode` and return a list of entities accordingly.

# %%
### BEGIN SOLUTION
def get_filtered_test_sample(head, relation, tail, test_dataset: Dataset) -> List:
    filtered_sample = []

    if test_dataset.mode == 'head-batch':
        for candidate_head in range(test_dataset.nentity):
            if (candidate_head, relation, tail) in test_dataset.triple_set:
                filtered_sample.append(head)
            else:
                filtered_sample.append(candidate_head)

    elif test_dataset.mode == 'tail-batch':
        for candidate_tail in range(test_dataset.nentity):
            if (head, relation, candidate_tail) in test_dataset.triple_set:
                filtered_sample.append(tail)
            else:
                filtered_sample.append(candidate_tail)

    else:
        raise ValueError('negative batch mode %s not supported' % test_dataset.mode)

    return filtered_sample
### END SOLUTION

# %% [markdown]
# Now we can use our filtered test sampling function to define our test dataset.

# %%
class TestDataset(Dataset):
    def __init__(self, triples, all_true_triples, nentity, nrelation, mode):
        self.len = len(triples)
        self.triple_set = set(all_true_triples) # set of all known true triples
        self.triples = triples # test triples
        self.nentity = nentity
        self.nrelation = nrelation
        self.mode = mode # 'head-batch' or 'tail-batch'

    def __len__(self):
        return self.len

    def __getitem__(self, idx):
        head, relation, tail = self.triples[idx] # fetch a positive sample from the test triples

        # get the filtered sample using the function we defined
        filtered_sample = get_filtered_test_sample(head, relation, tail, self)

        # convert to torch tensors
        filtered_sample = torch.LongTensor(filtered_sample)
        positive_sample = torch.LongTensor((head, relation, tail))

        return positive_sample, filtered_sample, self.mode

    @staticmethod
    def collate_fn(data):
        positive_sample = torch.stack([_[0] for _ in data], dim=0)
        negative_sample = torch.stack([_[1] for _ in data], dim=0)
        mode = data[0][2]
        return positive_sample, negative_sample, mode

# %% [markdown]
# ## Dataset Iterator
# As a final step towards constructing our datasets, we define a class that allows us to convert `torch` dataloaders into python iterators, which will make it simpler for us to define training and testing step functions.

# %%
class OneShotIterator:
    def __init__(self, dataloader):
        self.iterator = self.one_shot_iterator(dataloader)

    def __next__(self):
        return next(self.iterator)

    @staticmethod
    def one_shot_iterator(dataloader):
        '''
        Transform a PyTorch Dataloader into python iterator
        '''
        while True:
            for data in dataloader:
                yield data

# %% [markdown]
# We will create the actual train and test datasets in code further below, but here follows some code for constructing them, in case you would like to use them for debugging.

# %%
# make the train dataloader
train_dataloader = DataLoader(
    TrainDataset(train_triples,
                 14, # nentity
                 55, # nrelation
                 128), # negative sampling size
    batch_size=500,
    shuffle=True,
    num_workers=1,
    collate_fn=TrainDataset.collate_fn
)
# convert to an iterator
train_iterator = OneShotIterator(train_dataloader)
# get a sample from the train iterator
positive_sample, negative_sample = next(train_iterator)

# %% [markdown]
# If your code is correct, the following output should be `torch.Size([500, 128, 3])`.

# %%
negative_sample.size()
# Out:
# torch.Size([500, 128, 3])

# %%
# make the test dataloader
known_true_triples = train_triples + valid_triples + test_triples
test_dataloader_head = DataLoader(
    TestDataset(
        test_triples,
        known_true_triples,
        14, # nentity
        55, # nrelation
        'head-batch'
    ),
    batch_size=1,
    num_workers=1,
    collate_fn=TestDataset.collate_fn
)

# %% [markdown]
# If your code is correct, the following output should be `torch.Size([1, 14])`.

# %%
for positive_sample, negative_sample, mode in test_dataloader_head:
    print(negative_sample.size())
    break
# Out:
# torch.Size([1, 14])

# %% [markdown]
# # Model
# We now define our model, `KGEModel`. It is built in such a way that we can implement different dissimilarity measures within it.
#
# From here onwards, we will be working with `torch` tensors instead of `numpy` arrays, so make sure you are using `torch` operations.

# %% [markdown]
# ## Parameter Initialisation
# We will use `torch.nn.Parameter` to store our embeddings for entities and relations. We define a function `init_params` which initialises an embedding tensor of the given size and randomly samples values from the uniform distribution `[-embedding_range, embedding_range]`.

# %%
def init_params(tensor_size: tuple, embedding_range: float) -> nn.Parameter:
    embedding = nn.Parameter(torch.zeros(tensor_size))
    nn.init.uniform_(
        tensor=embedding,
        a=-embedding_range,
        b=embedding_range
    )
    return embedding

# %% [markdown]
# ## Scoring Function
# Different KG embedding models use different dissimilarity measures (aka scoring functions). We will define one for **TransE** and optionally define one for **RotatE**.

# %% [markdown]
# #### Task 5
# Define a scoring function for **TransE** that takes in the head, relation, and tail, and returns a score for the triple. Each argument tensor has size `[batch_size, embedding_size]`. You may use either the $L_1$ or $L_2$ norm. Your output tensor should have size `[batch_size]`.

# %%
### BEGIN SOLUTION
def TransE(head, relation, tail):
    score = torch.norm(head + relation - tail, p=2, dim=1)
    return score
### END SOLUTION

# %% [markdown]
# ### Task 6 (Optional)
# This is an optional task. You should get **TransE** working completely first and then come back to this.
#
# Define a scoring function for **RotatE**. The head and tail will have size `[batch_size, 2 * embedding_size]` to store both the real and imaginary parts of the entities. *Hint: you can use `torch.chunk()` to split the tensor into its real and imaginary components*.
#
# The relation will have size `[batch_size, embedding_size]`, representing the phase $\theta$ of the relation. *Hint: The real and imaginary components of the relation can be computed with `torch.cos` and `torch.sin`*.

# %%
import torch.nn as nn

seed = 42
set_seeds(seed)
dataset = load_dataset("CiteSeer")

data = dataset[0].to("cuda")

scaler = StandardScaler()


num_nodes = data.num_nodes
train_mask, val_mask, test_mask = create_custom_masks(num_nodes, train_ratio=0.8, val_ratio=0.1, test_ratio=0.1)

class VGAE_Encoder(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, latent_channels):
        super(VGAE_Encoder, self).__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv_mu = GCNConv(hidden_channels, latent_channels)
        self.conv_logvar = GCNConv(hidden_channels, latent_channels)
        self.dropout = nn.Dropout(0)


    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        x = self.dropout(F.relu(self.conv2(x, edge_index)))
        mu = self.conv_mu(x, edge_index)
        logvar = self.conv_logvar(x, edge_index)
        return mu, logvar


in_channels = dataset.num_node_features
hidden_channels = 64
latent_channels = 64

encoder = VGAE_Encoder(in_channels, hidden_channels, latent_channels)
my_model = VGAE(encoder).to("cuda")

optimizer = torch.optim.Adam(my_model.parameters(), lr=0.005, weight_decay=1e-3)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=15, gamma=0.9)

best_val_auc = 0
best_acc = 0
wait = 0
patience = 50
best_model_state = None

negative_pool = []
with torch.no_grad():
    z_neg = my_model.encode(data.x, data.edge_index)
    negative_pool.append(z_neg)
negative_pool = torch.cat(negative_pool, dim=0).detach()

val_idx = torch.where(data.val_mask)[0]
val_auc_history = []
val_ap_history = []
val_acc_history = []
val_nmi_history = []
val_ari_history = []

from torch_geometric.utils import add_self_loops

for epoch in range(1000):
    my_model.train()
    optimizer.zero_grad()

    total_loss = 0
    total_recon_loss = 0
    total_kl_loss = 0
    total_contrastive_loss = 0
    total_sim_reg = 0

    train_x = data.x[train_mask]
    train_edge_index = filter_edges(data.edge_index, train_mask)
    train_edge_index = remap_edge_index(train_edge_index, train_mask)


    torch_state = torch.get_rng_state()
    cuda_state = torch.cuda.get_rng_state()

    x_aug1, edge_index_aug1 = apply_augmentations(train_edge_index, train_x, p_edge=0.1, p_node=0.1, p_feature=0.1, noise_std=0.1)

    torch.set_rng_state(torch_state)
    torch.cuda.set_rng_state(cuda_state)
    torch_state = torch.get_rng_state()
    cuda_state = torch.cuda.get_rng_state()
    x_aug2, edge_index_aug2 = apply_augmentations(train_edge_index, train_x, p_edge=0.1, p_node=0.1, p_feature=0.1, noise_std=0.1)

    torch.set_rng_state(torch_state)
    torch.cuda.set_rng_state(cuda_state)

    assert torch.equal(torch_state, torch.get_rng_state()), "Torch RNG state changed!"
    assert torch.equal(cuda_state, torch.cuda.get_rng_state()), "CUDA RNG state changed!"


    z1 = my_model.encode(x_aug1, edge_index_aug1)
    z2 = my_model.encode(x_aug2, edge_index_aug2)

    z_neg = sample_negatives(z1, negative_pool, num_negatives=8192)

    recon_loss = my_model.recon_loss(z1, train_edge_index)
    kl_loss = my_model.kl_loss()
    contrastive_loss_value = contrastive_loss_with_negatives(z1, z2, z_neg, tau=0.2)
    contrastive_loss_value += contrastive_loss_with_negatives(z2, z1, z_neg, tau=0.2)



    pos_sim = F.cosine_similarity(z1, z2, dim=1).mean().item()
    neg_sim = torch.mean(torch.mm(z1, z_neg.T)).item()
    sim_reg = pos_sim - neg_sim


    recon_weight = 30
    kl_weight = min(0.002 + epoch / 500, 0.5)

    contrastive_weight = min(15 + epoch / 20, 50)


    loss = recon_weight * recon_loss + kl_weight * kl_loss + contrastive_weight * contrastive_loss_value - 20 * sim_reg

    # loss = recon_weight * recon_loss +  kl_weight * kl_loss


    loss.backward()

    torch.nn.utils.clip_grad_norm_(my_model.parameters(), max_norm=5.0)
    optimizer.step()

    total_loss += loss.item()
    total_recon_loss += recon_weight * recon_loss
    total_kl_loss += kl_weight * kl_loss
    total_contrastive_loss += contrastive_weight * contrastive_loss_value
    total_sim_reg += sim_reg

    scheduler.step()

    # Validation
    if epoch % 10 == 0:
        val_auc, val_ap = evaluate_model(my_model, data.edge_index, data.x, data.y, val_mask)
        val_auc_history.append(val_auc)
        val_ap_history.append(val_ap)
        acc, nmi, ari = evaluate_node_clustering(my_model, data)
        val_acc_history.append(acc)
        val_nmi_history.append(nmi)
        val_ari_history.append(ari)
        print(f"Epoch {epoch}, Validation AUC: {val_auc:.4f}, Validation AP: {val_ap:.4f}")
        print(f"Epoch {epoch}, Pos Sim: {pos_sim:.4f}, Neg Sim: {neg_sim:.4f}")
        print(f"Epoch {epoch}, Total Loss: {total_loss:.4f}, Recon Loss: {total_recon_loss:.4f}, KL Loss: {total_kl_loss:.4f}, Contrastive Loss: {total_contrastive_loss:.4f}, sim reg: {total_sim_reg:.4f}, Learning Rate = {optimizer.param_groups[0]['lr']:.6f}")

    if acc > best_acc:
      best_acc = acc
      wait = 0
      best_model_state = my_model.state_dict()
    else:
      wait += 1
      if wait >= patience:
        print(f"Early stopping at epoch {epoch}")
        break


my_model.load_state_dict(best_model_state)

test_auc, test_ap = evaluate_model(my_model, data.edge_index, data.x, data.y, test_mask)
print(f"Test AUC: {test_auc:.4f}, Test AP: {test_ap:.4f}")

acc, nmi, ari = evaluate_node_clustering(my_model, data)
print(f"Clustering Results: ACC={acc:.4f}, NMI={nmi:.4f}, ARI={ari:.4f}")


import matplotlib.pyplot as plt
plt.plot(val_auc_history, label='Validation AUC')
plt.plot(val_ap_history, label='Validation AP')
plt.plot(val_acc_history, label='Validation ACC')
plt.plot(val_nmi_history, label='Validation NMI')
plt.plot(val_ari_history, label='Validation ARI')
plt.xlabel('Epochs')
plt.ylabel('Metrics')
plt.legend()
plt.show()

# %%
### BEGIN SOLUTION
def RotatE(head, relation, tail):
    head_real, head_imag = torch.chunk(head, 2, dim=1)
    tail_real, tail_imag = torch.chunk(tail, 2, dim=1)

    relation_real = torch.cos(relation)
    relation_imag = torch.sin(relation)

    rotated_head_real = head_real * relation_real - head_imag * relation_imag
    rotated_head_imag = head_real * relation_imag + head_imag * relation_real

    real_diff = rotated_head_real - tail_real
    imag_diff = rotated_head_imag - tail_imag

    score = torch.norm(real_diff, p=2, dim=1) + torch.norm(imag_diff, p=2, dim=1)
    return score

### END SOLUTION

# %% [markdown]
# the objective is to rotate the head embedding by the phase angle of the relation so that it closely matches the tail embedding.
#
# rotation is applied by rotating the head embedding in the complex space by the phase angle $\theta$ using Euler's formula:
#
# $
# h_{\text{rotated}} = (h_{\text{real}} \cdot \cos(\theta) - h_{\text{imag}} \cdot \sin(\theta)) + i \cdot (h_{\text{real}} \cdot \sin(\theta) + h_{\text{imag}} \cdot \cos(\theta))
# $

# %% [markdown]
# ## Full Model Definition
# Now we can use our scoring function to define the model. Notice that in the `forward` function, we use `torch.index_select` to fetch the entity / relation embeddings from the their indices. `sample` is a tensor with the size `[batch_size, 3]`.

# %%
class KGEModel(nn.Module):
    def __init__(self, model_name: str, nentity: int, nrelation: int, hidden_dim: int, gamma: float,
                 double_entity_embedding: bool=False, double_relation_embedding: bool=False):
        super(KGEModel, self).__init__()
        self.model_name = model_name
        self.nentity = nentity
        self.nrelation = nrelation
        self.hidden_dim = hidden_dim
        self.epsilon = 2.0

        self.gamma = nn.Parameter(
            torch.Tensor([gamma]),
            requires_grad=False
        )

        self.embedding_range = nn.Parameter(
            torch.Tensor([(self.gamma.item() + self.epsilon) / hidden_dim]),
            requires_grad=False
        )

        self.entity_dim = 2*hidden_dim if double_entity_embedding else hidden_dim
        self.relation_dim = 2*hidden_dim if double_relation_embedding else hidden_dim

        # Create entity and relation embeddings
        self.entity_embedding = init_params(tensor_size=(nentity, self.entity_dim),
                                             embedding_range=self.embedding_range.item())
        self.relation_embedding = init_params(tensor_size=(nrelation, self.relation_dim),
                                              embedding_range=self.embedding_range.item())

        # This code supports easily adding new models like RotatE and ComplEx
        # Do not forget to modify this line when you add a new model in the "forward" function
        if model_name not in ['TransE', 'RotatE']:
            raise ValueError('model %s not supported' % model_name)

        if model_name == 'RotatE' and not double_entity_embedding:
            raise ValueError('RotatE should use --double_entity_embedding')
        if model_name == 'TransE' and double_entity_embedding:
            raise ValueError('TransE should not use --double_entity_embedding')

    def forward(self, sample):
        '''
        Forward function that calculate the score of a batch of triples.
        Sample is a batch of triples.
        '''
        head = torch.index_select(
            self.entity_embedding,
            dim=0,
            index=sample[:,0]
        )

        relation = torch.index_select(
            self.relation_embedding,
            dim=0,
            index=sample[:,1]
        )

        tail = torch.index_select(
            self.entity_embedding,
            dim=0,
            index=sample[:,2]
        )

        # Other models can be added here
        dissimilarity_measure = {
            'TransE': TransE,
            'RotatE': RotatE,
        }

        if self.model_name in dissimilarity_measure:
            score = dissimilarity_measure[self.model_name](head, relation, tail)
        else:
            raise ValueError('model %s not supported' % self.model_name)

        return score

# %% [markdown]
# # Training
# In this section, we will first write a function to compute the model loss given a set of positive and negative samples, and then use it to define a single training step for the model.

# %% [markdown]
# #### Task 7
# Before we can define a training step for our model, we must define a loss function for the model. We use negative sampling loss (from the **RotatE** paper), but without the self-adversarial parameter. Remember to refer to the lecture slides if you get stuck on this.
#
# Define a function `get_model_loss` which takes in the `KGEModel`, the positive sample, and the negative sample, and returns a tuple of the loss, the positive sample loss, and the negative sample loss.
#
# The positive sample will have size `[batch_size, 3]`, the negative sample will have size `[batch_size * negative_sampling_size, 3]`, and the margin $\gamma$ can be accessed through `model.gamma`.

# %%
### BEGIN SOLUTION
def get_model_loss(model: KGEModel, positive_sample: torch.tensor, negative_sample: torch.tensor) -> Tuple:
    gamma = model.gamma

    positive_score = gamma - model(positive_sample)
    positive_sample_loss = - torch.mean(F.logsigmoid(positive_score))

    negative_score = model(negative_sample) - gamma
    negative_sample_loss = -torch.mean(F.logsigmoid(negative_score))

    loss = positive_sample_loss + negative_sample_loss

    return loss, positive_sample_loss, negative_sample_loss
### END SOLUTION

# %% [markdown]
# We can now define a single train step for the model.

# %%
def train_step(model, optimizer, train_iterator, args):
    '''
    A single train step. Apply back-propation and return the loss
    '''

    model.train() # tell the torch model it's about to be trained

    optimizer.zero_grad() # explicitly set gradients to 0 before starting backprop

    positive_sample, negative_sample = next(train_iterator) # fetch samples from the dataset

    # reshape the negative sample
    # it will now have shape [batch_size * negative_sampling_size, 3]
    negative_sample = torch.reshape(negative_sample, (-1, 3))

    # move tensors to GPU
    if args.cuda:
        positive_sample = positive_sample.cuda()
        negative_sample = negative_sample.cuda()

    # compute the loss
    loss, positive_sample_loss, negative_sample_loss = get_model_loss(model, positive_sample, negative_sample)

    # apply loss
    loss.backward()
    optimizer.step()

    log = {
        'positive_sample_loss': positive_sample_loss.item(),
        'negative_sample_loss': negative_sample_loss.item(),
        'loss': loss.item()
    }

    return log

# %% [markdown]
# # Testing
# In this section, we will first write a function to get the ranking of a positive entity compared to its corrupted counterparts, and then use that to define a single test step for the model.

# %% [markdown]
# #### Task 8

# %% [markdown]
# Define a function `get_ranking` which takes in entity scores and the index of the positive entity. The function should return an integer representing the rank of the score of the positive entity in relation to the other entities. Note that a rank of 1 represents having the *lowest* score.
#
# `entity_scores` has size `[nentity]`. Recall from the function we defined further above that we filtered out known true triples by replacing the corrupted heads with the actual head, so some of the entity scores may actually be that of the positive entity, even when they are not in the index of that entity.
#
# *Hint: torch.argsort will be very useful for this task*.

# %%
### BEGIN SOLUTION
def get_ranking(entity_scores: torch.tensor, positive_entity: int) -> int:
    sorted_indices = torch.argsort(entity_scores)
    ranking = torch.where(sorted_indices == positive_entity)[0].item() + 1

    return ranking
### END SOLUTION

# %% [markdown]
# We can now define a single test step for the model, using the ranking function to compute MRR, MR, and HITS@k metrics.

# %%
def test_step(model, test_triples, all_true_triples, args):
    '''
    Evaluate the model on test or valid datasets
    '''

    model.eval()

    #Prepare dataloader for evaluation
    test_dataloader_head = DataLoader(
        TestDataset(
            test_triples,
            all_true_triples,
            args.nentity,
            args.nrelation,
            'head-batch'
        ),
        batch_size=args.test_batch_size,
        num_workers=max(1, args.cpu_num//2),
        collate_fn=TestDataset.collate_fn
    )

    test_dataloader_tail = DataLoader(
        TestDataset(
            test_triples,
            all_true_triples,
            args.nentity,
            args.nrelation,
            'tail-batch'
        ),
        batch_size=args.test_batch_size,
        num_workers=max(1, args.cpu_num//2),
        collate_fn=TestDataset.collate_fn
    )

    test_dataset_list = [test_dataloader_head, test_dataloader_tail]

    logs = []

    step = 0
    total_steps = sum([len(dataset) for dataset in test_dataset_list])

    # torch.no_grad() since we don't need to track gradients when we're testing
    with torch.no_grad():
        for test_dataset in test_dataset_list: # each of head / tail
            for positive_sample, negative_sample, mode in test_dataset:
                # take a sample from the test dataset
                if args.cuda:
                    positive_sample = positive_sample.cuda()
                    negative_sample = negative_sample.cuda()

                batch_size = positive_sample.size(0)
                assert batch_size == 1, 'evaluation batch size must be set to 1'

                # build the negative sample from the entities
                # currently, negative_sample is just a list of entities
                # [1, 14, 3] for Nations
                built_negative_sample = torch.zeros((batch_size, negative_sample.size()[1], 3), dtype=int)
                if args.cuda:
                    built_negative_sample = built_negative_sample.cuda()

                if mode == 'head-batch':
                    built_negative_sample[:, :, 0] = negative_sample
                    built_negative_sample[:, :, 1:3] = positive_sample[:, 1:3].unsqueeze(dim=1).expand((-1, built_negative_sample.size(1), -1))
                else:
                    built_negative_sample[:, :, 2] = negative_sample
                    built_negative_sample[:, :, 0:2] = positive_sample[:, 0:2].unsqueeze(dim=1).expand((-1, built_negative_sample.size(1), -1))

                # get the scores for each entity
                negative_sample = built_negative_sample.reshape((-1, 3))
                entity_scores = model(negative_sample)

                # retrieve the positive entity
                if mode == 'head-batch':
                    positive_entity = positive_sample[:, 0].item()
                elif mode == 'tail-batch':
                    positive_entity = positive_sample[:, 2].item()
                else:
                    raise ValueError('mode %s not supported' % mode)

                # get the ranking of the positive entity
                ranking = get_ranking(entity_scores, positive_entity)

                # compute and append logs
                logs.append({
                    'MRR': 1.0/ranking,
                    'MR': float(ranking),
                    'HITS@1': 1.0 if ranking <= 1 else 0.0,
                    'HITS@3': 1.0 if ranking <= 3 else 0.0,
                    'HITS@10': 1.0 if ranking <= 10 else 0.0,
                })

                if step % args.test_log_steps == 0:
                    print('Evaluating the model... (%d/%d)' % (step, total_steps))

                step += 1

    metrics = {}
    for metric in logs[0].keys():
        metrics[metric] = sum([log[metric] for log in logs])/len(logs)

    return metrics

# %% [markdown]
# # Running
# To make the running of experiments easier, we will define several help functions.

# %% [markdown]
# ## Arguments
# `argparse` is a very useful library for managing program arguments, particulary when executing from the command line. Default arguments are defined here. If you want to change argument values, do not do it in this block of code, rather change them in the arguments that are passed through to the program (see further below).

# %%
def parse_args(args=None):
    parser = argparse.ArgumentParser(
        description='Training and Testing Knowledge Graph Embedding Models',
        usage='train.py [<args>] [-h | --help]'
    )

    parser.add_argument('--cuda', action='store_true', help='use GPU')

    parser.add_argument('--do_train', action='store_true')
    parser.add_argument('--do_valid', action='store_true')
    parser.add_argument('--do_test', action='store_true')
    parser.add_argument('--evaluate_train', action='store_true', help='Evaluate on training data')

    parser.add_argument('--model', default='TransE', type=str)
    parser.add_argument('-de', '--double_entity_embedding', action='store_true')
    parser.add_argument('-dr', '--double_relation_embedding', action='store_true')

    parser.add_argument('-n', '--negative_sample_size', default=128, type=int)
    parser.add_argument('-d', '--hidden_dim', default=100, type=int, help='Embedding size')
    parser.add_argument('-g', '--gamma', default=2.0, type=float, help='Fixed margin parameter')
    parser.add_argument('-b', '--batch_size', default=1024, type=int)
    parser.add_argument('--test_batch_size', default=1, type=int, help='valid/test batch size (must be 1)')

    parser.add_argument('-lr', '--learning_rate', default=0.0001, type=float)
    parser.add_argument('-cpu', '--cpu_num', default=1, type=int)
    parser.add_argument('--max_steps', default=100, type=int)

    parser.add_argument('--valid_steps', default=20, type=int, help='how often to check accuracy on validation dataset')
    parser.add_argument('--log_steps', default=10, type=int, help='train log every xx steps')
    parser.add_argument('--test_log_steps', default=1000, type=int, help='valid/test log every xx steps')

    parser.add_argument('--nentity', type=int, default=0, help='DO NOT MANUALLY SET')
    parser.add_argument('--nrelation', type=int, default=0, help='DO NOT MANUALLY SET')

    parser.parse_args(args)
    return parser.parse_args(args)

# %% [markdown]
# ## Logging
# The below function is used to help with logging metrics.

# %%
def log_metrics(mode, step, metrics):
    '''
    Print the evaluation logs
    '''
    for metric in metrics:
        print('%s %s at step %d: %f' % (mode, metric, step, metrics[metric]))

# %% [markdown]
# ## Main Program Loop
# We can finally bring everything we've done together into the main program loop. Please refer to the comments in the code to understand how it operates.

# %%
def main(args):
    if (not args.do_train) and (not args.do_valid) and (not args.do_test):
        raise ValueError('one of train/val/test mode must be chosen.')

    # use CUDA if possible
    args.cuda = torch.cuda.is_available()

    # print dataset parameters
    entity2id = dataset.training.entity_to_id
    relation2id = dataset.training.relation_to_id

    nentity = len(entity2id)
    nrelation = len(relation2id)

    args.nentity = nentity
    args.nrelation = nrelation

    print('Model: %s' % args.model)
    print('#entity: %d' % nentity)
    print('#relation: %d' % nrelation)

    print('#train: %d' % len(train_triples))
    print('#valid: %d' % len(valid_triples))
    print('#test: %d' % len(test_triples))

    # all true triples
    all_true_triples = train_triples + valid_triples + test_triples

    # create the model
    kge_model = KGEModel(
        model_name=args.model,
        nentity=nentity,
        nrelation=nrelation,
        hidden_dim=args.hidden_dim,
        gamma=args.gamma,
        double_entity_embedding=args.double_entity_embedding,
        double_relation_embedding=args.double_relation_embedding
    )

    # output the model params
    print('\nModel Parameter Configuration:')
    for name, param in kge_model.named_parameters():
        print('Parameter %s: %s, require_grad = %s' % (name, str(param.size()), str(param.requires_grad)))

    if args.cuda:
        kge_model = kge_model.cuda()

    if args.do_train:
        # set training dataloader iterator
        train_dataloader = DataLoader(
            TrainDataset(train_triples, nentity, nrelation, args.negative_sample_size),
            batch_size=args.batch_size,
            shuffle=True,
            num_workers=max(1, args.cpu_num//2),
            collate_fn=TrainDataset.collate_fn
        )
        train_iterator = OneShotIterator(train_dataloader)

        # set training configuration
        optimizer = torch.optim.Adam(
            filter(lambda p: p.requires_grad, kge_model.parameters()),
            lr=args.learning_rate
        )

    init_step = 1
    step = init_step

    # do an initial evaluation to see metrics for a random model
    print('\nEvaluating initial model on Valid Dataset...')
    metrics = test_step(kge_model, valid_triples, all_true_triples, args)
    log_metrics('Valid', step, metrics)

    # log training parameters
    print('\nStart Training...')
    print('init_step = %d' % init_step)
    print('batch_size = %d' % args.batch_size)
    print('hidden_dim = %d' % args.hidden_dim)
    print('gamma = %f' % args.gamma)

    if args.do_train:
        print('learning_rate = %f' % args.learning_rate)

        training_logs = []

        # training loop
        for step in range(init_step, args.max_steps):
            # perform a single train step
            log = train_step(kge_model, optimizer, train_iterator, args)

            # record the logs
            training_logs.append(log)

            # check if logs should be displayed
            if step % args.log_steps == 0:
                metrics = {}
                for metric in training_logs[0].keys():
                    metrics[metric] = sum([log[metric] for log in training_logs])/len(training_logs)
                print('\nTraining metrics...')
                log_metrics('Training average', step, metrics)
                training_logs = []

            # check if metrics should be reported on the validation set
            if args.do_valid and step % args.valid_steps == 0:
                print('\nEvaluating on Valid Dataset...')
                metrics = test_step(kge_model, valid_triples, all_true_triples, args)
                log_metrics('Valid', step, metrics)

    # compute final metrics after training is complete

    if args.do_valid:
        print('Evaluating on Valid Dataset...')
        metrics = test_step(kge_model, valid_triples, all_true_triples, args)
        log_metrics('Valid', step, metrics)

    if args.do_test:
        print('Evaluating on Test Dataset...')
        metrics = test_step(kge_model, test_triples, all_true_triples, args)
        log_metrics('Test', step, metrics)

    if args.evaluate_train:
        print('Evaluating on Training Dataset...')
        metrics = test_step(kge_model, train_triples, all_true_triples, args)
        log_metrics('Test', step, metrics)

# %% [markdown]
# The below code can be used to run the main program loop. Model arguments can be adjusted by changing / adding / removing the arguments.

# %%
if __name__ == '__main__':
    main(parse_args(['--do_train', '--do_valid', '--do_test',
                     '--model', 'TransE',
                     '--max_steps', '1000', '--valid_steps', '20', '--log_steps', '10']))
# Out:
# Model: TransE
# #entity: 14
# #relation: 55
# #train: 1592
# #valid: 199
# #test: 201
#
# Model Parameter Configuration:
# Parameter gamma: torch.Size([1]), require_grad = False
# Parameter embedding_range: torch.Size([1]), require_grad = False
# Parameter entity_embedding: torch.Size([14, 100]), require_grad = True
# Parameter relation_embedding: torch.Size([55, 100]), require_grad = True
#
# Evaluating initial model on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 1: 0.158280
# Valid MR at step 1: 8.002513
# Valid HITS@1 at step 1: 0.000000
# Valid HITS@3 at step 1: 0.090452
# Valid HITS@10 at step 1: 0.773869
#
# Start Training...
# init_step = 1
# batch_size = 1024
# hidden_dim = 100
# gamma = 2.000000
# learning_rate = 0.000100
#
# Training metrics...
# Training average positive_sample_loss at step 10: 0.185742
# Training average negative_sample_loss at step 10: 1.796414
# Training average loss at step 10: 1.982156
#
# Training metrics...
# Training average positive_sample_loss at step 20: 0.188381
# Training average negative_sample_loss at step 20: 1.784537
# Training average loss at step 20: 1.972918
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 20: 0.158214
# Valid MR at step 20: 8.032663
# Valid HITS@1 at step 20: 0.000000
# Valid HITS@3 at step 20: 0.095477
# Valid HITS@10 at step 20: 0.768844
#
# Training metrics...
# Training average positive_sample_loss at step 30: 0.191018
# Training average negative_sample_loss at step 30: 1.772588
# Training average loss at step 30: 1.963606
#
# Training metrics...
# Training average positive_sample_loss at step 40: 0.193734
# Training average negative_sample_loss at step 40: 1.760384
# Training average loss at step 40: 1.954118
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 40: 0.158418
# Valid MR at step 40: 8.027638
# Valid HITS@1 at step 40: 0.000000
# Valid HITS@3 at step 40: 0.095477
# Valid HITS@10 at step 40: 0.776382
#
# Training metrics...
# Training average positive_sample_loss at step 50: 0.196511
# Training average negative_sample_loss at step 50: 1.748286
# Training average loss at step 50: 1.944797
#
# Training metrics...
# Training average positive_sample_loss at step 60: 0.199420
# Training average negative_sample_loss at step 60: 1.735963
# Training average loss at step 60: 1.935383
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 60: 0.158561
# Valid MR at step 60: 8.007538
# Valid HITS@1 at step 60: 0.000000
# Valid HITS@3 at step 60: 0.097990
# Valid HITS@10 at step 60: 0.771357
#
# Training metrics...
# Training average positive_sample_loss at step 70: 0.202282
# Training average negative_sample_loss at step 70: 1.723560
# Training average loss at step 70: 1.925842
#
# Training metrics...
# Training average positive_sample_loss at step 80: 0.205271
# Training average negative_sample_loss at step 80: 1.711046
# Training average loss at step 80: 1.916317
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 80: 0.158998
# Valid MR at step 80: 8.005025
# Valid HITS@1 at step 80: 0.000000
# Valid HITS@3 at step 80: 0.100503
# Valid HITS@10 at step 80: 0.763819
#
# Training metrics...
# Training average positive_sample_loss at step 90: 0.208263
# Training average negative_sample_loss at step 90: 1.698545
# Training average loss at step 90: 1.906808
#
# Training metrics...
# Training average positive_sample_loss at step 100: 0.211423
# Training average negative_sample_loss at step 100: 1.686182
# Training average loss at step 100: 1.897605
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 100: 0.158709
# Valid MR at step 100: 7.992462
# Valid HITS@1 at step 100: 0.000000
# Valid HITS@3 at step 100: 0.097990
# Valid HITS@10 at step 100: 0.768844
#
# Training metrics...
# Training average positive_sample_loss at step 110: 0.214561
# Training average negative_sample_loss at step 110: 1.673665
# Training average loss at step 110: 1.888225
#
# Training metrics...
# Training average positive_sample_loss at step 120: 0.217730
# Training average negative_sample_loss at step 120: 1.661062
# Training average loss at step 120: 1.878791
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 120: 0.157748
# Valid MR at step 120: 8.030151
# Valid HITS@1 at step 120: 0.000000
# Valid HITS@3 at step 120: 0.095477
# Valid HITS@10 at step 120: 0.766332
#
# Training metrics...
# Training average positive_sample_loss at step 130: 0.220939
# Training average negative_sample_loss at step 130: 1.648450
# Training average loss at step 130: 1.869390
#
# Training metrics...
# Training average positive_sample_loss at step 140: 0.224281
# Training average negative_sample_loss at step 140: 1.635914
# Training average loss at step 140: 1.860195
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 140: 0.158790
# Valid MR at step 140: 7.987437
# Valid HITS@1 at step 140: 0.000000
# Valid HITS@3 at step 140: 0.095477
# Valid HITS@10 at step 140: 0.776382
#
# Training metrics...
# Training average positive_sample_loss at step 150: 0.227619
# Training average negative_sample_loss at step 150: 1.623418
# Training average loss at step 150: 1.851037
#
# Training metrics...
# Training average positive_sample_loss at step 160: 0.230953
# Training average negative_sample_loss at step 160: 1.611013
# Training average loss at step 160: 1.841967
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 160: 0.158809
# Valid MR at step 160: 7.937186
# Valid HITS@1 at step 160: 0.000000
# Valid HITS@3 at step 160: 0.092965
# Valid HITS@10 at step 160: 0.781407
#
# Training metrics...
# Training average positive_sample_loss at step 170: 0.234345
# Training average negative_sample_loss at step 170: 1.598648
# Training average loss at step 170: 1.832993
#
# Training metrics...
# Training average positive_sample_loss at step 180: 0.237882
# Training average negative_sample_loss at step 180: 1.586354
# Training average loss at step 180: 1.824236
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 180: 0.158909
# Valid MR at step 180: 7.959799
# Valid HITS@1 at step 180: 0.000000
# Valid HITS@3 at step 180: 0.092965
# Valid HITS@10 at step 180: 0.771357
#
# Training metrics...
# Training average positive_sample_loss at step 190: 0.241421
# Training average negative_sample_loss at step 190: 1.573838
# Training average loss at step 190: 1.815260
#
# Training metrics...
# Training average positive_sample_loss at step 200: 0.244886
# Training average negative_sample_loss at step 200: 1.561796
# Training average loss at step 200: 1.806683
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 200: 0.158717
# Valid MR at step 200: 7.929648
# Valid HITS@1 at step 200: 0.000000
# Valid HITS@3 at step 200: 0.090452
# Valid HITS@10 at step 200: 0.776382
#
# Training metrics...
# Training average positive_sample_loss at step 210: 0.248468
# Training average negative_sample_loss at step 210: 1.549356
# Training average loss at step 210: 1.797824
#
# Training metrics...
# Training average positive_sample_loss at step 220: 0.252052
# Training average negative_sample_loss at step 220: 1.537491
# Training average loss at step 220: 1.789544
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 220: 0.157738
# Valid MR at step 220: 7.932161
# Valid HITS@1 at step 220: 0.000000
# Valid HITS@3 at step 220: 0.087940
# Valid HITS@10 at step 220: 0.773869
#
# Training metrics...
# Training average positive_sample_loss at step 230: 0.255739
# Training average negative_sample_loss at step 230: 1.525284
# Training average loss at step 230: 1.781024
#
# Training metrics...
# Training average positive_sample_loss at step 240: 0.259276
# Training average negative_sample_loss at step 240: 1.513513
# Training average loss at step 240: 1.772790
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 240: 0.158561
# Valid MR at step 240: 7.891960
# Valid HITS@1 at step 240: 0.000000
# Valid HITS@3 at step 240: 0.090452
# Valid HITS@10 at step 240: 0.778894
#
# Training metrics...
# Training average positive_sample_loss at step 250: 0.263013
# Training average negative_sample_loss at step 250: 1.501676
# Training average loss at step 250: 1.764690
#
# Training metrics...
# Training average positive_sample_loss at step 260: 0.266694
# Training average negative_sample_loss at step 260: 1.490180
# Training average loss at step 260: 1.756874
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 260: 0.158838
# Valid MR at step 260: 7.884422
# Valid HITS@1 at step 260: 0.000000
# Valid HITS@3 at step 260: 0.090452
# Valid HITS@10 at step 260: 0.781407
#
# Training metrics...
# Training average positive_sample_loss at step 270: 0.270401
# Training average negative_sample_loss at step 270: 1.478453
# Training average loss at step 270: 1.748854
#
# Training metrics...
# Training average positive_sample_loss at step 280: 0.274142
# Training average negative_sample_loss at step 280: 1.466871
# Training average loss at step 280: 1.741014
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 280: 0.159329
# Valid MR at step 280: 7.881910
# Valid HITS@1 at step 280: 0.000000
# Valid HITS@3 at step 280: 0.092965
# Valid HITS@10 at step 280: 0.778894
#
# Training metrics...
# Training average positive_sample_loss at step 290: 0.277851
# Training average negative_sample_loss at step 290: 1.455618
# Training average loss at step 290: 1.733469
#
# Training metrics...
# Training average positive_sample_loss at step 300: 0.281615
# Training average negative_sample_loss at step 300: 1.444459
# Training average loss at step 300: 1.726074
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 300: 0.160016
# Valid MR at step 300: 7.866834
# Valid HITS@1 at step 300: 0.000000
# Valid HITS@3 at step 300: 0.095477
# Valid HITS@10 at step 300: 0.781407
#
# Training metrics...
# Training average positive_sample_loss at step 310: 0.285565
# Training average negative_sample_loss at step 310: 1.433176
# Training average loss at step 310: 1.718741
#
# Training metrics...
# Training average positive_sample_loss at step 320: 0.289288
# Training average negative_sample_loss at step 320: 1.421932
# Training average loss at step 320: 1.711220
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 320: 0.160618
# Valid MR at step 320: 7.826633
# Valid HITS@1 at step 320: 0.000000
# Valid HITS@3 at step 320: 0.090452
# Valid HITS@10 at step 320: 0.786432
#
# Training metrics...
# Training average positive_sample_loss at step 330: 0.293184
# Training average negative_sample_loss at step 330: 1.410812
# Training average loss at step 330: 1.703996
#
# Training metrics...
# Training average positive_sample_loss at step 340: 0.296890
# Training average negative_sample_loss at step 340: 1.400526
# Training average loss at step 340: 1.697416
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 340: 0.160867
# Valid MR at step 340: 7.839196
# Valid HITS@1 at step 340: 0.000000
# Valid HITS@3 at step 340: 0.090452
# Valid HITS@10 at step 340: 0.788945
#
# Training metrics...
# Training average positive_sample_loss at step 350: 0.300807
# Training average negative_sample_loss at step 350: 1.389558
# Training average loss at step 350: 1.690365
#
# Training metrics...
# Training average positive_sample_loss at step 360: 0.304582
# Training average negative_sample_loss at step 360: 1.378899
# Training average loss at step 360: 1.683481
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 360: 0.161792
# Valid MR at step 360: 7.819095
# Valid HITS@1 at step 360: 0.000000
# Valid HITS@3 at step 360: 0.092965
# Valid HITS@10 at step 360: 0.786432
#
# Training metrics...
# Training average positive_sample_loss at step 370: 0.308458
# Training average negative_sample_loss at step 370: 1.368349
# Training average loss at step 370: 1.676807
#
# Training metrics...
# Training average positive_sample_loss at step 380: 0.312370
# Training average negative_sample_loss at step 380: 1.358060
# Training average loss at step 380: 1.670430
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 380: 0.162090
# Valid MR at step 380: 7.801508
# Valid HITS@1 at step 380: 0.000000
# Valid HITS@3 at step 380: 0.092965
# Valid HITS@10 at step 380: 0.788945
#
# Training metrics...
# Training average positive_sample_loss at step 390: 0.316214
# Training average negative_sample_loss at step 390: 1.347865
# Training average loss at step 390: 1.664079
#
# Training metrics...
# Training average positive_sample_loss at step 400: 0.320083
# Training average negative_sample_loss at step 400: 1.337803
# Training average loss at step 400: 1.657886
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 400: 0.163494
# Valid MR at step 400: 7.751256
# Valid HITS@1 at step 400: 0.000000
# Valid HITS@3 at step 400: 0.095477
# Valid HITS@10 at step 400: 0.791457
#
# Training metrics...
# Training average positive_sample_loss at step 410: 0.323918
# Training average negative_sample_loss at step 410: 1.328003
# Training average loss at step 410: 1.651921
#
# Training metrics...
# Training average positive_sample_loss at step 420: 0.327937
# Training average negative_sample_loss at step 420: 1.318065
# Training average loss at step 420: 1.646002
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 420: 0.163782
# Valid MR at step 420: 7.726131
# Valid HITS@1 at step 420: 0.000000
# Valid HITS@3 at step 420: 0.095477
# Valid HITS@10 at step 420: 0.793970
#
# Training metrics...
# Training average positive_sample_loss at step 430: 0.331759
# Training average negative_sample_loss at step 430: 1.308300
# Training average loss at step 430: 1.640059
#
# Training metrics...
# Training average positive_sample_loss at step 440: 0.335462
# Training average negative_sample_loss at step 440: 1.298508
# Training average loss at step 440: 1.633970
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 440: 0.164599
# Valid MR at step 440: 7.698492
# Valid HITS@1 at step 440: 0.000000
# Valid HITS@3 at step 440: 0.097990
# Valid HITS@10 at step 440: 0.796482
#
# Training metrics...
# Training average positive_sample_loss at step 450: 0.339327
# Training average negative_sample_loss at step 450: 1.288771
# Training average loss at step 450: 1.628098
#
# Training metrics...
# Training average positive_sample_loss at step 460: 0.343253
# Training average negative_sample_loss at step 460: 1.279810
# Training average loss at step 460: 1.623063
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 460: 0.164338
# Valid MR at step 460: 7.716080
# Valid HITS@1 at step 460: 0.000000
# Valid HITS@3 at step 460: 0.097990
# Valid HITS@10 at step 460: 0.796482
#
# Training metrics...
# Training average positive_sample_loss at step 470: 0.347094
# Training average negative_sample_loss at step 470: 1.270262
# Training average loss at step 470: 1.617356
#
# Training metrics...
# Training average positive_sample_loss at step 480: 0.350943
# Training average negative_sample_loss at step 480: 1.261401
# Training average loss at step 480: 1.612344
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 480: 0.165048
# Valid MR at step 480: 7.675879
# Valid HITS@1 at step 480: 0.000000
# Valid HITS@3 at step 480: 0.100503
# Valid HITS@10 at step 480: 0.806533
#
# Training metrics...
# Training average positive_sample_loss at step 490: 0.354727
# Training average negative_sample_loss at step 490: 1.252127
# Training average loss at step 490: 1.606854
#
# Training metrics...
# Training average positive_sample_loss at step 500: 0.358541
# Training average negative_sample_loss at step 500: 1.243210
# Training average loss at step 500: 1.601751
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 500: 0.166583
# Valid MR at step 500: 7.638191
# Valid HITS@1 at step 500: 0.000000
# Valid HITS@3 at step 500: 0.105528
# Valid HITS@10 at step 500: 0.806533
#
# Training metrics...
# Training average positive_sample_loss at step 510: 0.362307
# Training average negative_sample_loss at step 510: 1.234490
# Training average loss at step 510: 1.596798
#
# Training metrics...
# Training average positive_sample_loss at step 520: 0.366193
# Training average negative_sample_loss at step 520: 1.225847
# Training average loss at step 520: 1.592040
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 520: 0.166860
# Valid MR at step 520: 7.628141
# Valid HITS@1 at step 520: 0.000000
# Valid HITS@3 at step 520: 0.110553
# Valid HITS@10 at step 520: 0.806533
#
# Training metrics...
# Training average positive_sample_loss at step 530: 0.369752
# Training average negative_sample_loss at step 530: 1.217525
# Training average loss at step 530: 1.587276
#
# Training metrics...
# Training average positive_sample_loss at step 540: 0.373660
# Training average negative_sample_loss at step 540: 1.208966
# Training average loss at step 540: 1.582626
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 540: 0.166734
# Valid MR at step 540: 7.625628
# Valid HITS@1 at step 540: 0.000000
# Valid HITS@3 at step 540: 0.110553
# Valid HITS@10 at step 540: 0.811558
#
# Training metrics...
# Training average positive_sample_loss at step 550: 0.377322
# Training average negative_sample_loss at step 550: 1.200799
# Training average loss at step 550: 1.578121
#
# Training metrics...
# Training average positive_sample_loss at step 560: 0.381110
# Training average negative_sample_loss at step 560: 1.192554
# Training average loss at step 560: 1.573664
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 560: 0.168291
# Valid MR at step 560: 7.587940
# Valid HITS@1 at step 560: 0.000000
# Valid HITS@3 at step 560: 0.115578
# Valid HITS@10 at step 560: 0.816583
#
# Training metrics...
# Training average positive_sample_loss at step 570: 0.384845
# Training average negative_sample_loss at step 570: 1.184481
# Training average loss at step 570: 1.569326
#
# Training metrics...
# Training average positive_sample_loss at step 580: 0.388563
# Training average negative_sample_loss at step 580: 1.176631
# Training average loss at step 580: 1.565194
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 580: 0.168905
# Valid MR at step 580: 7.552764
# Valid HITS@1 at step 580: 0.000000
# Valid HITS@3 at step 580: 0.113065
# Valid HITS@10 at step 580: 0.824121
#
# Training metrics...
# Training average positive_sample_loss at step 590: 0.391998
# Training average negative_sample_loss at step 590: 1.168945
# Training average loss at step 590: 1.560943
#
# Training metrics...
# Training average positive_sample_loss at step 600: 0.395813
# Training average negative_sample_loss at step 600: 1.161069
# Training average loss at step 600: 1.556882
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 600: 0.169410
# Valid MR at step 600: 7.527638
# Valid HITS@1 at step 600: 0.000000
# Valid HITS@3 at step 600: 0.120603
# Valid HITS@10 at step 600: 0.826633
#
# Training metrics...
# Training average positive_sample_loss at step 610: 0.399418
# Training average negative_sample_loss at step 610: 1.153449
# Training average loss at step 610: 1.552867
#
# Training metrics...
# Training average positive_sample_loss at step 620: 0.402938
# Training average negative_sample_loss at step 620: 1.145792
# Training average loss at step 620: 1.548729
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 620: 0.170280
# Valid MR at step 620: 7.502513
# Valid HITS@1 at step 620: 0.000000
# Valid HITS@3 at step 620: 0.120603
# Valid HITS@10 at step 620: 0.826633
#
# Training metrics...
# Training average positive_sample_loss at step 630: 0.406596
# Training average negative_sample_loss at step 630: 1.138376
# Training average loss at step 630: 1.544972
#
# Training metrics...
# Training average positive_sample_loss at step 640: 0.410104
# Training average negative_sample_loss at step 640: 1.130936
# Training average loss at step 640: 1.541040
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 640: 0.170632
# Valid MR at step 640: 7.492462
# Valid HITS@1 at step 640: 0.000000
# Valid HITS@3 at step 640: 0.123116
# Valid HITS@10 at step 640: 0.829146
#
# Training metrics...
# Training average positive_sample_loss at step 650: 0.413621
# Training average negative_sample_loss at step 650: 1.124004
# Training average loss at step 650: 1.537625
#
# Training metrics...
# Training average positive_sample_loss at step 660: 0.416978
# Training average negative_sample_loss at step 660: 1.117226
# Training average loss at step 660: 1.534204
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 660: 0.170716
# Valid MR at step 660: 7.482412
# Valid HITS@1 at step 660: 0.000000
# Valid HITS@3 at step 660: 0.123116
# Valid HITS@10 at step 660: 0.831658
#
# Training metrics...
# Training average positive_sample_loss at step 670: 0.420473
# Training average negative_sample_loss at step 670: 1.110129
# Training average loss at step 670: 1.530602
#
# Training metrics...
# Training average positive_sample_loss at step 680: 0.424009
# Training average negative_sample_loss at step 680: 1.103173
# Training average loss at step 680: 1.527182
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 680: 0.170793
# Valid MR at step 680: 7.487437
# Valid HITS@1 at step 680: 0.000000
# Valid HITS@3 at step 680: 0.125628
# Valid HITS@10 at step 680: 0.829146
#
# Training metrics...
# Training average positive_sample_loss at step 690: 0.427311
# Training average negative_sample_loss at step 690: 1.096181
# Training average loss at step 690: 1.523492
#
# Training metrics...
# Training average positive_sample_loss at step 700: 0.430704
# Training average negative_sample_loss at step 700: 1.089599
# Training average loss at step 700: 1.520303
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 700: 0.171176
# Valid MR at step 700: 7.469849
# Valid HITS@1 at step 700: 0.000000
# Valid HITS@3 at step 700: 0.125628
# Valid HITS@10 at step 700: 0.831658
#
# Training metrics...
# Training average positive_sample_loss at step 710: 0.433854
# Training average negative_sample_loss at step 710: 1.083376
# Training average loss at step 710: 1.517230
#
# Training metrics...
# Training average positive_sample_loss at step 720: 0.437236
# Training average negative_sample_loss at step 720: 1.077045
# Training average loss at step 720: 1.514281
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 720: 0.171476
# Valid MR at step 720: 7.462312
# Valid HITS@1 at step 720: 0.000000
# Valid HITS@3 at step 720: 0.128141
# Valid HITS@10 at step 720: 0.829146
#
# Training metrics...
# Training average positive_sample_loss at step 730: 0.440783
# Training average negative_sample_loss at step 730: 1.070112
# Training average loss at step 730: 1.510895
#
# Training metrics...
# Training average positive_sample_loss at step 740: 0.443653
# Training average negative_sample_loss at step 740: 1.064063
# Training average loss at step 740: 1.507716
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 740: 0.172232
# Valid MR at step 740: 7.422111
# Valid HITS@1 at step 740: 0.000000
# Valid HITS@3 at step 740: 0.128141
# Valid HITS@10 at step 740: 0.834171
#
# Training metrics...
# Training average positive_sample_loss at step 750: 0.447149
# Training average negative_sample_loss at step 750: 1.057961
# Training average loss at step 750: 1.505111
#
# Training metrics...
# Training average positive_sample_loss at step 760: 0.450084
# Training average negative_sample_loss at step 760: 1.052322
# Training average loss at step 760: 1.502406
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 760: 0.173218
# Valid MR at step 760: 7.409548
# Valid HITS@1 at step 760: 0.000000
# Valid HITS@3 at step 760: 0.130653
# Valid HITS@10 at step 760: 0.831658
#
# Training metrics...
# Training average positive_sample_loss at step 770: 0.453105
# Training average negative_sample_loss at step 770: 1.046266
# Training average loss at step 770: 1.499371
#
# Training metrics...
# Training average positive_sample_loss at step 780: 0.456500
# Training average negative_sample_loss at step 780: 1.040060
# Training average loss at step 780: 1.496560
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 780: 0.174452
# Valid MR at step 780: 7.384422
# Valid HITS@1 at step 780: 0.000000
# Valid HITS@3 at step 780: 0.140704
# Valid HITS@10 at step 780: 0.834171
#
# Training metrics...
# Training average positive_sample_loss at step 790: 0.459542
# Training average negative_sample_loss at step 790: 1.034808
# Training average loss at step 790: 1.494351
#
# Training metrics...
# Training average positive_sample_loss at step 800: 0.462546
# Training average negative_sample_loss at step 800: 1.028969
# Training average loss at step 800: 1.491516
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 800: 0.175068
# Valid MR at step 800: 7.361809
# Valid HITS@1 at step 800: 0.000000
# Valid HITS@3 at step 800: 0.143216
# Valid HITS@10 at step 800: 0.831658
#
# Training metrics...
# Training average positive_sample_loss at step 810: 0.465265
# Training average negative_sample_loss at step 810: 1.023406
# Training average loss at step 810: 1.488670
#
# Training metrics...
# Training average positive_sample_loss at step 820: 0.468402
# Training average negative_sample_loss at step 820: 1.018023
# Training average loss at step 820: 1.486425
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 820: 0.175104
# Valid MR at step 820: 7.364322
# Valid HITS@1 at step 820: 0.000000
# Valid HITS@3 at step 820: 0.145729
# Valid HITS@10 at step 820: 0.826633
#
# Training metrics...
# Training average positive_sample_loss at step 830: 0.471348
# Training average negative_sample_loss at step 830: 1.012406
# Training average loss at step 830: 1.483754
#
# Training metrics...
# Training average positive_sample_loss at step 840: 0.474261
# Training average negative_sample_loss at step 840: 1.006888
# Training average loss at step 840: 1.481149
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 840: 0.175679
# Valid MR at step 840: 7.356784
# Valid HITS@1 at step 840: 0.000000
# Valid HITS@3 at step 840: 0.148241
# Valid HITS@10 at step 840: 0.829146
#
# Training metrics...
# Training average positive_sample_loss at step 850: 0.476769
# Training average negative_sample_loss at step 850: 1.001966
# Training average loss at step 850: 1.478735
#
# Training metrics...
# Training average positive_sample_loss at step 860: 0.479979
# Training average negative_sample_loss at step 860: 0.996866
# Training average loss at step 860: 1.476845
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 860: 0.175683
# Valid MR at step 860: 7.344221
# Valid HITS@1 at step 860: 0.000000
# Valid HITS@3 at step 860: 0.150754
# Valid HITS@10 at step 860: 0.831658
#
# Training metrics...
# Training average positive_sample_loss at step 870: 0.482569
# Training average negative_sample_loss at step 870: 0.991792
# Training average loss at step 870: 1.474361
#
# Training metrics...
# Training average positive_sample_loss at step 880: 0.485625
# Training average negative_sample_loss at step 880: 0.986685
# Training average loss at step 880: 1.472310
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 880: 0.175936
# Valid MR at step 880: 7.334171
# Valid HITS@1 at step 880: 0.000000
# Valid HITS@3 at step 880: 0.150754
# Valid HITS@10 at step 880: 0.834171
#
# Training metrics...
# Training average positive_sample_loss at step 890: 0.488228
# Training average negative_sample_loss at step 890: 0.981831
# Training average loss at step 890: 1.470060
#
# Training metrics...
# Training average positive_sample_loss at step 900: 0.490693
# Training average negative_sample_loss at step 900: 0.977248
# Training average loss at step 900: 1.467941
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 900: 0.176276
# Valid MR at step 900: 7.304020
# Valid HITS@1 at step 900: 0.000000
# Valid HITS@3 at step 900: 0.150754
# Valid HITS@10 at step 900: 0.839196
#
# Training metrics...
# Training average positive_sample_loss at step 910: 0.493225
# Training average negative_sample_loss at step 910: 0.972324
# Training average loss at step 910: 1.465550
#
# Training metrics...
# Training average positive_sample_loss at step 920: 0.495966
# Training average negative_sample_loss at step 920: 0.967805
# Training average loss at step 920: 1.463771
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 920: 0.177003
# Valid MR at step 920: 7.273869
# Valid HITS@1 at step 920: 0.000000
# Valid HITS@3 at step 920: 0.150754
# Valid HITS@10 at step 920: 0.844221
#
# Training metrics...
# Training average positive_sample_loss at step 930: 0.498546
# Training average negative_sample_loss at step 930: 0.963736
# Training average loss at step 930: 1.462282
#
# Training metrics...
# Training average positive_sample_loss at step 940: 0.500916
# Training average negative_sample_loss at step 940: 0.959062
# Training average loss at step 940: 1.459978
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 940: 0.177044
# Valid MR at step 940: 7.263819
# Valid HITS@1 at step 940: 0.000000
# Valid HITS@3 at step 940: 0.150754
# Valid HITS@10 at step 940: 0.844221
#
# Training metrics...
# Training average positive_sample_loss at step 950: 0.503526
# Training average negative_sample_loss at step 950: 0.954231
# Training average loss at step 950: 1.457757
#
# Training metrics...
# Training average positive_sample_loss at step 960: 0.506250
# Training average negative_sample_loss at step 960: 0.949874
# Training average loss at step 960: 1.456124
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 960: 0.177045
# Valid MR at step 960: 7.258794
# Valid HITS@1 at step 960: 0.000000
# Valid HITS@3 at step 960: 0.148241
# Valid HITS@10 at step 960: 0.844221
#
# Training metrics...
# Training average positive_sample_loss at step 970: 0.508392
# Training average negative_sample_loss at step 970: 0.945854
# Training average loss at step 970: 1.454246
#
# Training metrics...
# Training average positive_sample_loss at step 980: 0.511220
# Training average negative_sample_loss at step 980: 0.941679
# Training average loss at step 980: 1.452899
#
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 980: 0.178164
# Valid MR at step 980: 7.243719
# Valid HITS@1 at step 980: 0.000000
# Valid HITS@3 at step 980: 0.150754
# Valid HITS@10 at step 980: 0.846734
#
# Training metrics...
# Training average positive_sample_loss at step 990: 0.513102
# Training average negative_sample_loss at step 990: 0.937508
# Training average loss at step 990: 1.450610
# Evaluating on Valid Dataset...
# Evaluating the model... (0/398)
# Valid MRR at step 999: 0.178091
# Valid MR at step 999: 7.268844
# Valid HITS@1 at step 999: 0.000000
# Valid HITS@3 at step 999: 0.150754
# Valid HITS@10 at step 999: 0.844221
# Evaluating on Test Dataset...
# Evaluating the model... (0/402)
# Test MRR at step 999: 0.175996
# Test MR at step 999: 7.437811
# Test HITS@1 at step 999: 0.000000
# Test HITS@3 at step 999: 0.149254
# Test HITS@10 at step 999: 0.800995
